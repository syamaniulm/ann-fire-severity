# %%
# Artificial Neural Network Regression

import numpy as np
import math
import pandas as pd
import matplotlib.pyplot as plt
import pickle
import dataframe_image as dfi
import warnings

from sklearn.linear_model import LinearRegression
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_percentage_error as mape
from sklearn.metrics import mean_squared_error as mse
from tqdm.auto import tqdm

warnings.filterwarnings('ignore')

# Vegetation indices list

veg_indices = ['SAVI', 'NDVI', 'TSAVI', 'MSAVI', 'DVI', 'RVI', 'PVI', 'IPVI', 'WDVI', 'TNDVI', 'GNDVI', 'GEMI', 'ARVI', 'NDI45', 'MCARI', 'EVI', 'S2REP', 'IRECI', 'PSSRa', 'ARI', 'GLI', 'LCI', 'CVI', 'CRI550', 'CRI700']

# Reading data file

training_data = pd.read_csv('Ground_Samples/Training_Data.csv')

y_train = training_data.iloc[:,3]

validation_data = pd.read_csv('Ground_Samples/Validation_Data.csv')
y_test = validation_data.iloc[:,3]

# Batch regression analysis

nn_r2_1h = []
nn_mape_1h = []
nn_rmse_1h = []

nn_r2_2h = []
nn_mape_2h = []
nn_rmse_2h = []

nn_r2_3h = []
nn_mape_3h = []
nn_rmse_3h = []

nn_r2_4h = []
nn_mape_4h = []
nn_rmse_4h = []

nn_r2_5h = []
nn_mape_5h = []
nn_rmse_5h = []

nn_r2_6h = []
nn_mape_6h = []
nn_rmse_6h = []

for i in tqdm(range(25)):
    
    x_train = training_data.iloc[:,[i+4,i+29,i+54]]
    x_test = validation_data.iloc[:,[i+4,i+29,i+54]]
    
    # Neural network regression model with 1 hidden layer
    
    nn_reg_1h = MLPRegressor(hidden_layer_sizes=(100,), random_state=1, max_iter=1000)
    nn_reg_1h.fit(x_train, y_train)
    y_train_pred = nn_reg_1h.predict(x_train)
    y_test_pred = nn_reg_1h.predict(x_test)
    nn_r2_1h.append(round(r2_score(y_train, y_train_pred),4))
    nn_mape_1h.append(round(mape(y_test, y_test_pred)*100,2))
    nn_rmse_1h.append(round(math.sqrt(mse(y_test, y_test_pred)*100),4))

    # Neural network regression model with 2 hidden layers
    
    nn_reg_2h = MLPRegressor(hidden_layer_sizes=(100,100,), random_state=1, max_iter=1000)
    nn_reg_2h.fit(x_train, y_train)
    y_train_pred = nn_reg_2h.predict(x_train)
    y_test_pred = nn_reg_2h.predict(x_test)
    nn_r2_2h.append(round(r2_score(y_train, y_train_pred),4))
    nn_mape_2h.append(round(mape(y_test, y_test_pred)*100,2))
    nn_rmse_2h.append(round(math.sqrt(mse(y_test, y_test_pred)*100),4))
    
    # Neural network regression model with 3 hidden layers
    
    nn_reg_3h = MLPRegressor(hidden_layer_sizes=(100,100,100,), random_state=1, max_iter=1000)
    nn_reg_3h.fit(x_train, y_train)
    y_train_pred = nn_reg_3h.predict(x_train)
    y_test_pred = nn_reg_3h.predict(x_test)
    nn_r2_3h.append(round(r2_score(y_train, y_train_pred),4))
    nn_mape_3h.append(round(mape(y_test, y_test_pred)*100,2))
    nn_rmse_3h.append(round(math.sqrt(mse(y_test, y_test_pred)*100),4))
    
    # Neural network regression model with 4 hidden layers
    
    nn_reg_4h = MLPRegressor(hidden_layer_sizes=(100,100,100,100,), random_state=1, max_iter=1000)
    nn_reg_4h.fit(x_train, y_train)
    y_train_pred = nn_reg_4h.predict(x_train)
    y_test_pred = nn_reg_4h.predict(x_test)
    nn_r2_4h.append(round(r2_score(y_train, y_train_pred),4))
    nn_mape_4h.append(round(mape(y_test, y_test_pred)*100,2))
    nn_rmse_4h.append(round(math.sqrt(mse(y_test, y_test_pred)*100),4))
    
    # Neural network regression model with 5 hidden layers
    
    nn_reg_5h = MLPRegressor(hidden_layer_sizes=(100,100,100,100,100,), random_state=1, max_iter=1000)
    nn_reg_5h.fit(x_train, y_train)
    y_train_pred = nn_reg_5h.predict(x_train)
    y_test_pred = nn_reg_5h.predict(x_test)
    nn_r2_5h.append(round(r2_score(y_train, y_train_pred),4))
    nn_mape_5h.append(round(mape(y_test, y_test_pred)*100,2))
    nn_rmse_5h.append(round(math.sqrt(mse(y_test, y_test_pred)*100),4))
    
    # Neural network regression model with 6 hidden layers
    
    nn_reg_6h = MLPRegressor(hidden_layer_sizes=(100,100,100,100,100,100,), random_state=1, max_iter=1000)
    nn_reg_6h.fit(x_train, y_train)
    y_train_pred = nn_reg_6h.predict(x_train)
    y_test_pred = nn_reg_6h.predict(x_test)
    nn_r2_6h.append(round(r2_score(y_train, y_train_pred),4))
    nn_mape_6h.append(round(mape(y_test, y_test_pred)*100,2))
    nn_rmse_6h.append(round(math.sqrt(mse(y_test, y_test_pred)*100),4))
    
    # Saving neural network regression models
    
    fname_1h = './Models/' + veg_indices[i].lower() + '_nn_reg_1h_model.sav'
    fname_2h = './Models/' + veg_indices[i].lower() + '_nn_reg_2h_model.sav'
    fname_3h = './Models/' + veg_indices[i].lower() + '_nn_reg_3h_model.sav'
    fname_4h = './Models/' + veg_indices[i].lower() + '_nn_reg_4h_model.sav'
    fname_5h = './Models/' + veg_indices[i].lower() + '_nn_reg_5h_model.sav'
    fname_6h = './Models/' + veg_indices[i].lower() + '_nn_reg_6h_model.sav'
    
    pickle.dump(nn_reg_1h, open(fname_1h, 'wb'))
    pickle.dump(nn_reg_2h, open(fname_2h, 'wb'))
    pickle.dump(nn_reg_3h, open(fname_3h, 'wb'))
    pickle.dump(nn_reg_4h, open(fname_4h, 'wb'))
    pickle.dump(nn_reg_5h, open(fname_5h, 'wb'))
    pickle.dump(nn_reg_6h, open(fname_6h, 'wb'))

nn_reg_dict = {'R2 (1H)': nn_r2_1h, 'MAPE (1H)': nn_mape_1h, 'RMSE (1H)': nn_rmse_1h, 'R2 (2H)': nn_r2_2h, 'MAPE (2H)': nn_mape_2h, 'RMSE (2H)': nn_rmse_2h, 'R2 (3H)': nn_r2_3h, 'MAPE (3H)': nn_mape_3h, 'RMSE (3H)': nn_rmse_3h, 'R2 (4H)': nn_r2_4h, 'MAPE (4H)': nn_mape_4h, 'RMSE (4H)': nn_rmse_4h, 'R2 (5H)': nn_r2_5h, 'MAPE (5H)': nn_mape_5h, 'RMSE (5H)': nn_rmse_5h, 'R2 (6H)': nn_r2_6h, 'MAPE (6H)': nn_mape_6h, 'RMSE (6H)': nn_rmse_6h}
nn_reg_df = pd.DataFrame(nn_reg_dict, veg_indices, columns=['R2 (1H)', 'MAPE (1H)', 'RMSE (1H)', 'R2 (2H)', 'MAPE (2H)', 'RMSE (2H)', 'R2 (3H)', 'MAPE (3H)', 'RMSE (3H)', 'R2 (4H)', 'MAPE (4H)', 'RMSE (4H)', 'R2 (5H)', 'MAPE (5H)', 'RMSE (5H)', 'R2 (6H)', 'MAPE (6H)', 'RMSE (6H)'])

nn_reg_df_styled = nn_reg_df.style.background_gradient(cmap='YlOrRd')

nn_reg_df_styled

# dfi.export(nn_reg_df_styled, 'nn_regression.png')

# print('Processing completed...')
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]
# <style type="text/css">
# #T_c10ad_row0_col0, #T_c10ad_row0_col3, #T_c10ad_row0_col9, #T_c10ad_row0_col12, #T_c10ad_row0_col15, #T_c10ad_row2_col3, #T_c10ad_row3_col0, #T_c10ad_row3_col3, #T_c10ad_row3_col6, #T_c10ad_row3_col9, #T_c10ad_row3_col12, #T_c10ad_row3_col15, #T_c10ad_row4_col3, #T_c10ad_row6_col3, #T_c10ad_row8_col0, #T_c10ad_row8_col3, #T_c10ad_row8_col15, #T_c10ad_row11_col3, #T_c10ad_row14_col3, #T_c10ad_row15_col3, #T_c10ad_row16_col1, #T_c10ad_row16_col2, #T_c10ad_row16_col4, #T_c10ad_row16_col5, #T_c10ad_row16_col7, #T_c10ad_row16_col8, #T_c10ad_row16_col10, #T_c10ad_row16_col11, #T_c10ad_row16_col13, #T_c10ad_row16_col14, #T_c10ad_row16_col16, #T_c10ad_row16_col17, #T_c10ad_row17_col0, #T_c10ad_row17_col3, #T_c10ad_row17_col6, #T_c10ad_row17_col9, #T_c10ad_row17_col12, #T_c10ad_row17_col15 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_c10ad_row0_col1, #T_c10ad_row0_col2, #T_c10ad_row0_col4, #T_c10ad_row0_col5, #T_c10ad_row0_col11, #T_c10ad_row0_col14, #T_c10ad_row0_col16, #T_c10ad_row0_col17, #T_c10ad_row2_col5, #T_c10ad_row3_col1, #T_c10ad_row3_col2, #T_c10ad_row3_col4, #T_c10ad_row3_col5, #T_c10ad_row3_col8, #T_c10ad_row3_col11, #T_c10ad_row3_col14, #T_c10ad_row3_col16, #T_c10ad_row3_col17, #T_c10ad_row8_col1, #T_c10ad_row8_col4, #T_c10ad_row8_col5, #T_c10ad_row8_col16, #T_c10ad_row16_col0, #T_c10ad_row16_col3, #T_c10ad_row16_col6, #T_c10ad_row16_col9, #T_c10ad_row16_col12, #T_c10ad_row16_col15, #T_c10ad_row17_col1, #T_c10ad_row17_col2, #T_c10ad_row17_col4, #T_c10ad_row17_col5, #T_c10ad_row17_col7, #T_c10ad_row17_col8, #T_c10ad_row17_col10, #T_c10ad_row17_col11, #T_c10ad_row17_col13, #T_c10ad_row17_col14 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_c10ad_row0_col6, #T_c10ad_row1_col3, #T_c10ad_row2_col0, #T_c10ad_row2_col6, #T_c10ad_row2_col15, #T_c10ad_row4_col0, #T_c10ad_row5_col3, #T_c10ad_row6_col0, #T_c10ad_row8_col6, #T_c10ad_row8_col9, #T_c10ad_row8_col12, #T_c10ad_row11_col0, #T_c10ad_row13_col3, #T_c10ad_row14_col0, #T_c10ad_row15_col0, #T_c10ad_row18_col3, #T_c10ad_row20_col3 {
#   background-color: #820026;
#   color: #f1f1f1;
# }
# #T_c10ad_row0_col7, #T_c10ad_row1_col1, #T_c10ad_row15_col14, #T_c10ad_row15_col17 {
#   background-color: #fff8bb;
#   color: #000000;
# }
# #T_c10ad_row0_col8, #T_c10ad_row0_col13, #T_c10ad_row2_col1, #T_c10ad_row2_col2, #T_c10ad_row2_col8, #T_c10ad_row2_col16, #T_c10ad_row2_col17, #T_c10ad_row3_col7, #T_c10ad_row4_col1, #T_c10ad_row6_col1, #T_c10ad_row8_col8, #T_c10ad_row8_col11, #T_c10ad_row8_col13, #T_c10ad_row8_col14, #T_c10ad_row11_col1, #T_c10ad_row15_col1, #T_c10ad_row17_col16 {
#   background-color: #fffdc8;
#   color: #000000;
# }
# #T_c10ad_row0_col10, #T_c10ad_row3_col10, #T_c10ad_row4_col5, #T_c10ad_row6_col4, #T_c10ad_row6_col5, #T_c10ad_row14_col1, #T_c10ad_row14_col5, #T_c10ad_row15_col5 {
#   background-color: #fffec9;
#   color: #000000;
# }
# #T_c10ad_row1_col0, #T_c10ad_row9_col0, #T_c10ad_row11_col6, #T_c10ad_row15_col12, #T_c10ad_row15_col15, #T_c10ad_row23_col3 {
#   background-color: #8b0026;
#   color: #f1f1f1;
# }
# #T_c10ad_row1_col2, #T_c10ad_row7_col1, #T_c10ad_row10_col4, #T_c10ad_row23_col4 {
#   background-color: #fff5b5;
#   color: #000000;
# }
# #T_c10ad_row1_col4, #T_c10ad_row2_col13, #T_c10ad_row4_col2, #T_c10ad_row6_col2, #T_c10ad_row6_col13, #T_c10ad_row9_col4, #T_c10ad_row11_col2, #T_c10ad_row18_col5 {
#   background-color: #fffcc4;
#   color: #000000;
# }
# #T_c10ad_row1_col5, #T_c10ad_row4_col10, #T_c10ad_row4_col17, #T_c10ad_row5_col1, #T_c10ad_row6_col10, #T_c10ad_row7_col5, #T_c10ad_row9_col5, #T_c10ad_row14_col8, #T_c10ad_row15_col10, #T_c10ad_row15_col13, #T_c10ad_row20_col5 {
#   background-color: #fffac0;
#   color: #000000;
# }
# #T_c10ad_row1_col6, #T_c10ad_row21_col0 {
#   background-color: #9b0026;
#   color: #f1f1f1;
# }
# #T_c10ad_row1_col7, #T_c10ad_row1_col11, #T_c10ad_row1_col14, #T_c10ad_row12_col13, #T_c10ad_row20_col7 {
#   background-color: #ffe997;
#   color: #000000;
# }
# #T_c10ad_row1_col8, #T_c10ad_row1_col13, #T_c10ad_row7_col16, #T_c10ad_row9_col16, #T_c10ad_row18_col7, #T_c10ad_row18_col14, #T_c10ad_row18_col17 {
#   background-color: #ffefa4;
#   color: #000000;
# }
# #T_c10ad_row1_col9, #T_c10ad_row1_col12, #T_c10ad_row18_col9 {
#   background-color: #aa0026;
#   color: #f1f1f1;
# }
# #T_c10ad_row1_col10, #T_c10ad_row5_col16, #T_c10ad_row19_col4 {
#   background-color: #ffeea3;
#   color: #000000;
# }
# #T_c10ad_row1_col15, #T_c10ad_row5_col15, #T_c10ad_row7_col6, #T_c10ad_row23_col0 {
#   background-color: #a80026;
#   color: #f1f1f1;
# }
# #T_c10ad_row1_col16, #T_c10ad_row5_col8, #T_c10ad_row5_col13, #T_c10ad_row11_col7, #T_c10ad_row20_col8, #T_c10ad_row20_col13 {
#   background-color: #fff0a7;
#   color: #000000;
# }
# #T_c10ad_row1_col17, #T_c10ad_row7_col10, #T_c10ad_row11_col14, #T_c10ad_row20_col17, #T_c10ad_row21_col2 {
#   background-color: #ffea99;
#   color: #000000;
# }
# #T_c10ad_row2_col4, #T_c10ad_row3_col13, #T_c10ad_row4_col4, #T_c10ad_row8_col2, #T_c10ad_row8_col17, #T_c10ad_row14_col4, #T_c10ad_row15_col4, #T_c10ad_row17_col17 {
#   background-color: #fffecb;
#   color: #000000;
# }
# #T_c10ad_row2_col7, #T_c10ad_row4_col8, #T_c10ad_row5_col5, #T_c10ad_row8_col7, #T_c10ad_row14_col17, #T_c10ad_row15_col8, #T_c10ad_row18_col1 {
#   background-color: #fffac1;
#   color: #000000;
# }
# #T_c10ad_row2_col9, #T_c10ad_row2_col12, #T_c10ad_row7_col3, #T_c10ad_row9_col3, #T_c10ad_row12_col3 {
#   background-color: #840026;
#   color: #f1f1f1;
# }
# #T_c10ad_row2_col10, #T_c10ad_row4_col13, #T_c10ad_row4_col16, #T_c10ad_row5_col4, #T_c10ad_row13_col4, #T_c10ad_row14_col2, #T_c10ad_row14_col16 {
#   background-color: #fffcc5;
#   color: #000000;
# }
# #T_c10ad_row2_col11, #T_c10ad_row2_col14, #T_c10ad_row6_col16, #T_c10ad_row8_col10, #T_c10ad_row11_col4, #T_c10ad_row11_col5, #T_c10ad_row15_col2, #T_c10ad_row18_col4 {
#   background-color: #fffdc6;
#   color: #000000;
# }
# #T_c10ad_row4_col6, #T_c10ad_row15_col6 {
#   background-color: #860026;
#   color: #f1f1f1;
# }
# #T_c10ad_row4_col7, #T_c10ad_row20_col2 {
#   background-color: #fff7b7;
#   color: #000000;
# }
# #T_c10ad_row4_col9, #T_c10ad_row4_col12, #T_c10ad_row4_col15, #T_c10ad_row5_col0, #T_c10ad_row6_col6, #T_c10ad_row13_col0, #T_c10ad_row14_col6, #T_c10ad_row14_col15, #T_c10ad_row18_col0, #T_c10ad_row21_col3 {
#   background-color: #880026;
#   color: #f1f1f1;
# }
# #T_c10ad_row4_col11, #T_c10ad_row4_col14, #T_c10ad_row6_col8, #T_c10ad_row6_col17, #T_c10ad_row11_col16, #T_c10ad_row12_col5, #T_c10ad_row13_col1, #T_c10ad_row14_col7, #T_c10ad_row14_col10, #T_c10ad_row15_col7, #T_c10ad_row15_col16, #T_c10ad_row20_col1 {
#   background-color: #fff9be;
#   color: #000000;
# }
# #T_c10ad_row5_col2, #T_c10ad_row11_col8, #T_c10ad_row13_col2, #T_c10ad_row18_col2, #T_c10ad_row21_col4 {
#   background-color: #fff7b9;
#   color: #000000;
# }
# #T_c10ad_row5_col6, #T_c10ad_row13_col6 {
#   background-color: #990026;
#   color: #f1f1f1;
# }
# #T_c10ad_row5_col7, #T_c10ad_row5_col10, #T_c10ad_row7_col13, #T_c10ad_row13_col14, #T_c10ad_row13_col17 {
#   background-color: #ffec9d;
#   color: #000000;
# }
# #T_c10ad_row5_col9 {
#   background-color: #b00026;
#   color: #f1f1f1;
# }
# #T_c10ad_row5_col11, #T_c10ad_row9_col17, #T_c10ad_row10_col2 {
#   background-color: #ffe58f;
#   color: #000000;
# }
# #T_c10ad_row5_col12, #T_c10ad_row11_col12, #T_c10ad_row13_col15 {
#   background-color: #a40026;
#   color: #f1f1f1;
# }
# #T_c10ad_row5_col14, #T_c10ad_row12_col8, #T_c10ad_row20_col14, #T_c10ad_row23_col1 {
#   background-color: #ffeb9c;
#   color: #000000;
# }
# #T_c10ad_row5_col17, #T_c10ad_row13_col11 {
#   background-color: #ffea9b;
#   color: #000000;
# }
# #T_c10ad_row6_col7, #T_c10ad_row11_col13, #T_c10ad_row21_col5 {
#   background-color: #fff4b2;
#   color: #000000;
# }
# #T_c10ad_row6_col9, #T_c10ad_row6_col12, #T_c10ad_row6_col15, #T_c10ad_row10_col3, #T_c10ad_row11_col15, #T_c10ad_row14_col9, #T_c10ad_row15_col9, #T_c10ad_row20_col0 {
#   background-color: #8a0026;
#   color: #f1f1f1;
# }
# #T_c10ad_row6_col11, #T_c10ad_row6_col14, #T_c10ad_row11_col17, #T_c10ad_row14_col11, #T_c10ad_row14_col13, #T_c10ad_row15_col11 {
#   background-color: #fff9bd;
#   color: #000000;
# }
# #T_c10ad_row7_col0, #T_c10ad_row24_col3 {
#   backg

# %%
# Multiple Linear Regression

import numpy as np
import math
import pandas as pd
import matplotlib.pyplot as plt
import pickle
import dataframe_image as dfi
import warnings

from sklearn.linear_model import LinearRegression
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_percentage_error as mape
from sklearn.metrics import mean_squared_error as mse
from tqdm.auto import tqdm

warnings.filterwarnings('ignore')

# Vegetation indices list

veg_indices = ['SAVI', 'NDVI', 'TSAVI', 'MSAVI', 'DVI', 'RVI', 'PVI', 'IPVI', 'WDVI', 'TNDVI', 'GNDVI', 'GEMI', 'ARVI', 'NDI45', 'MCARI', 'EVI', 'S2REP', 'IRECI', 'PSSRa', 'ARI', 'GLI', 'LCI', 'CVI', 'CRI550', 'CRI700']

# Reading data file

training_data = pd.read_csv('Ground_Samples/Training_Data.csv')

y_train = training_data.iloc[:,3]

validation_data = pd.read_csv('Ground_Samples/Validation_Data.csv')
y_test = validation_data.iloc[:,3]

# Batch regression analysis

l_intercept = []
l_coef = np.empty((25,3))
l_r2 = []
l_mape = []
l_rmse = []

for i in tqdm(range(25)):
    
    x_train = training_data.iloc[:,[i+4,i+29,i+54]]
    x_test = validation_data.iloc[:,[i+4,i+29,i+54]]
    
    # Linear regression model
    
    l_reg = LinearRegression().fit(x_train, y_train)
    l_intercept.append(l_reg.intercept_)
    l_coef[i] = l_reg.coef_
    y_train_pred = l_reg.predict(x_train)
    y_test_pred = l_reg.predict(x_test)
    l_r2.append(round(r2_score(y_train, y_train_pred),4))
    l_mape.append(round(mape(y_test, y_test_pred)*100,2))
    l_rmse.append(round(math.sqrt(mse(y_test, y_test_pred)*100),4))
    
    # Saving linear regression models
    
    fname = './Models/' + veg_indices[i].lower() + '_l_reg_model.sav'
    
    pickle.dump(l_reg, open(fname, 'wb'))
    
l_reg_dict = {'Intercept': l_intercept, 'T1 Coef.': l_coef[:,0], 'T2 Coef.': l_coef[:,1], 'T3 Coef.': l_coef[:,2], 'R2': l_r2, 'MAPE': l_mape, 'RMSE': l_rmse}
l_reg_df = pd.DataFrame(l_reg_dict, veg_indices, columns=['Intercept', 'T1 Coef.', 'T2 Coef.', 'T3 Coef.', 'R2', 'MAPE', 'RMSE'])

l_reg_df_styled = l_reg_df.style.background_gradient(cmap='YlOrRd', subset=['R2','MAPE', 'RMSE'])

l_reg_df_styled

# dfi.export(l_reg_df_styled, 'l_regression.png')

# print('Processing completed...')
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]
# <style type="text/css">
# #T_2ad4c_row0_col4 {
#   background-color: #820026;
#   color: #f1f1f1;
# }
# #T_2ad4c_row0_col5, #T_2ad4c_row3_col5, #T_2ad4c_row3_col6, #T_2ad4c_row22_col4 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_2ad4c_row0_col6 {
#   background-color: #fffdc8;
#   color: #000000;
# }
# #T_2ad4c_row1_col4, #T_2ad4c_row7_col4 {
#   background-color: #c70723;
#   color: #f1f1f1;
# }
# #T_2ad4c_row1_col5, #T_2ad4c_row7_col5 {
#   background-color: #fee289;
#   color: #000000;
# }
# #T_2ad4c_row1_col6, #T_2ad4c_row7_col6 {
#   background-color: #fedb7a;
#   color: #000000;
# }
# #T_2ad4c_row2_col4 {
#   background-color: #8f0026;
#   color: #f1f1f1;
# }
# #T_2ad4c_row2_col5 {
#   background-color: #fffbc2;
#   color: #000000;
# }
# #T_2ad4c_row2_col6, #T_2ad4c_row8_col5, #T_2ad4c_row16_col4 {
#   background-color: #fff7b9;
#   color: #000000;
# }
# #T_2ad4c_row3_col4, #T_2ad4c_row22_col5, #T_2ad4c_row22_col6 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_2ad4c_row4_col4, #T_2ad4c_row6_col4, #T_2ad4c_row16_col5 {
#   background-color: #8a0026;
#   color: #f1f1f1;
# }
# #T_2ad4c_row4_col5, #T_2ad4c_row6_col5 {
#   background-color: #fffcc5;
#   color: #000000;
# }
# #T_2ad4c_row4_col6, #T_2ad4c_row6_col6 {
#   background-color: #fffac0;
#   color: #000000;
# }
# #T_2ad4c_row5_col4 {
#   background-color: #c20325;
#   color: #f1f1f1;
# }
# #T_2ad4c_row5_col5 {
#   background-color: #fee084;
#   color: #000000;
# }
# #T_2ad4c_row5_col6 {
#   background-color: #fee085;
#   color: #000000;
# }
# #T_2ad4c_row8_col4 {
#   background-color: #910026;
#   color: #f1f1f1;
# }
# #T_2ad4c_row8_col6 {
#   background-color: #fff6b6;
#   color: #000000;
# }
# #T_2ad4c_row9_col4, #T_2ad4c_row12_col4 {
#   background-color: #cb0a22;
#   color: #f1f1f1;
# }
# #T_2ad4c_row9_col5 {
#   background-color: #fede82;
#   color: #000000;
# }
# #T_2ad4c_row9_col6, #T_2ad4c_row12_col6 {
#   background-color: #fed572;
#   color: #000000;
# }
# #T_2ad4c_row10_col4 {
#   background-color: #fc612f;
#   color: #f1f1f1;
# }
# #T_2ad4c_row10_col5 {
#   background-color: #fd903d;
#   color: #000000;
# }
# #T_2ad4c_row10_col6 {
#   background-color: #fd863a;
#   color: #f1f1f1;
# }
# #T_2ad4c_row11_col4, #T_2ad4c_row16_col6 {
#   background-color: #950026;
#   color: #f1f1f1;
# }
# #T_2ad4c_row11_col5 {
#   background-color: #fff8bb;
#   color: #000000;
# }
# #T_2ad4c_row11_col6 {
#   background-color: #fff4b0;
#   color: #000000;
# }
# #T_2ad4c_row12_col5 {
#   background-color: #fedd7f;
#   color: #000000;
# }
# #T_2ad4c_row13_col4, #T_2ad4c_row20_col4 {
#   background-color: #aa0026;
#   color: #f1f1f1;
# }
# #T_2ad4c_row13_col5 {
#   background-color: #fff0a7;
#   color: #000000;
# }
# #T_2ad4c_row13_col6, #T_2ad4c_row20_col6 {
#   background-color: #ffeb9c;
#   color: #000000;
# }
# #T_2ad4c_row14_col4, #T_2ad4c_row19_col5 {
#   background-color: #970026;
#   color: #f1f1f1;
# }
# #T_2ad4c_row14_col5 {
#   background-color: #fff9bd;
#   color: #000000;
# }
# #T_2ad4c_row14_col6, #T_2ad4c_row19_col4 {
#   background-color: #fff3af;
#   color: #000000;
# }
# #T_2ad4c_row15_col4 {
#   background-color: #8b0026;
#   color: #f1f1f1;
# }
# #T_2ad4c_row15_col5 {
#   background-color: #fffcc4;
#   color: #000000;
# }
# #T_2ad4c_row15_col6 {
#   background-color: #fff9be;
#   color: #000000;
# }
# #T_2ad4c_row17_col4 {
#   background-color: #9b0026;
#   color: #f1f1f1;
# }
# #T_2ad4c_row17_col5 {
#   background-color: #fff1a9;
#   color: #000000;
# }
# #T_2ad4c_row17_col6 {
#   background-color: #fff2ac;
#   color: #000000;
# }
# #T_2ad4c_row18_col4 {
#   background-color: #bb0026;
#   color: #f1f1f1;
# }
# #T_2ad4c_row18_col5 {
#   background-color: #ffe48c;
#   color: #000000;
# }
# #T_2ad4c_row18_col6 {
#   background-color: #ffe48d;
#   color: #000000;
# }
# #T_2ad4c_row19_col6 {
#   background-color: #990026;
#   color: #f1f1f1;
# }
# #T_2ad4c_row20_col5 {
#   background-color: #ffefa5;
#   color: #000000;
# }
# #T_2ad4c_row21_col4, #T_2ad4c_row23_col6 {
#   background-color: #ef3323;
#   color: #f1f1f1;
# }
# #T_2ad4c_row21_col5 {
#   background-color: #feaf4b;
#   color: #000000;
# }
# #T_2ad4c_row21_col6 {
#   background-color: #fea647;
#   color: #000000;
# }
# #T_2ad4c_row23_col4 {
#   background-color: #fead4a;
#   color: #000000;
# }
# #T_2ad4c_row23_col5 {
#   background-color: #f64227;
#   color: #f1f1f1;
# }
# #T_2ad4c_row24_col4 {
#   background-color: #fec965;
#   color: #000000;
# }
# #T_2ad4c_row24_col5 {
#   background-color: #e1191d;
#   color: #f1f1f1;
# }
# #T_2ad4c_row24_col6 {
#   background-color: #dd161d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2ad4c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2ad4c_level0_col0" class="col_heading level0 col0" >Intercept</th>
#       <th id="T_2ad4c_level0_col1" class="col_heading level0 col1" >T1 Coef.</th>
#       <th id="T_2ad4c_level0_col2" class="col_heading level0 col2" >T2 Coef.</th>
#       <th id="T_2ad4c_level0_col3" class="col_heading level0 col3" >T3 Coef.</th>
#       <th id="T_2ad4c_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_2ad4c_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_2ad4c_level0_col6" class="col_heading level0 col6" >RMSE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2ad4c_level0_row0" class="row_heading level0 row0" >SAVI</th>
#       <td id="T_2ad4c_row0_col0" class="data row0 col0" >-0.123666</td>
#       <td id="T_2ad4c_row0_col1" class="data row0 col1" >0.169024</td>
#       <td id="T_2ad4c_row0_col2" class="data row0 col2" >0.284783</td>
#       <td id="T_2ad4c_row0_col3" class="data row0 col3" >1.592255</td>
#       <td id="T_2ad4c_row0_col4" class="data row0 col4" >0.872600</td>
#       <td id="T_2ad4c_row0_col5" class="data row0 col5" >12.690000</td>
#       <td id="T_2ad4c_row0_col6" class="data row0 col6" >0.772700</td>
#     </tr>
#     <tr>
#       <th id="T_2ad4c_level0_row1" class="row_heading level0 row1" >NDVI</th>
#       <td id="T_2ad4c_row1_col0" class="data row1 col0" >-0.477364</td>
#       <td id="T_2ad4c_row1_col1" class="data row1 col1" >0.652269</td>
#       <td id="T_2ad4c_row1_col2" class="data row1 col2" >0.198471</td>
#       <td id="T_2ad4c_row1_col3" class="data row1 col3" >0.806823</td>
#       <td id="T_2ad4c_row1_col4" class="data row1 col4" >0.765500</td>
#       <td id="T_2ad4c_row1_col5" class="data row1 col5" >16.820000</td>
#       <td id="T_2ad4c_row1_col6" class="data row1 col6" >1.048700</td>
#     </tr>
#     <tr>
#       <th id="T_2ad4c_level0_row2" class="row_heading level0 row2" >TSAVI</th>
#       <td id="T_2ad4c_row2_col0" class="data row2 col0" >-0.136734</td>
#       <td id="T_2ad4c_row2_col1" class="data row2 col1" >0.435236</td>
#       <td id="T_2ad4c_row2_col2" class="data row2 col2" >0.288191</td>
#       <td id="T_2ad4c_row2_col3" class="data row2 col3" >1.197367</td>
#       <td id="T_2ad4c_row2_col4" class="data row2 col4" >0.854200</td>
#       <td id="T_2ad4c_row2_col5" class="data row2 col5" >13.290000</td>
#       <td id="T_2ad4c_row2_col6" class="data row2 col6" >0.826400</td>
#     </tr>
#     <tr>
#       <th id="T_2ad4c_level0_row3" class="row_heading level0 row3" >MSAVI</th>
#       <td id="T_2ad4c_row3_col0" class="data row3 col0" >0.000952</td>
#       <td id="T_2ad4c_row3_col1" class="data row3 col1" >0.008612</td>
#       <td id="T_2ad4c_row3_col2" class="data row3 col2" >0.281907</td>
#       <td id="T_2ad4c_row3_col3" class="data row3 col3" >1.534187</td>
#       <td id="T_2ad4c_row3_col4" class="data row3 col4" >0.877800</td>
#       <td id="T_2ad4c_row3_col5" class="data row3 col5" >12.690000</td>
#       <td id="T_2ad4c_row3_col6" class="data row3 col6" >0.756600</td>
#     </tr>
#     <tr>
#       <th id="T_2ad4c_level0_row4" class="row_heading level0 row4" >DVI</th>
#       <td id="T_2ad4c_row4_col0" class="data row4 col0" >0.016070</td>
#       <td id="T_2ad4c_row4_col1" class="data row4 col1" >-0.129305</td>
#       <td id="T_2ad4c_row4_col2" class="data row4 col2" >0.158230</td>
#       <td id="T_2ad4c_row4_col3" class="data row4 col3" >3.024061</td>
#       <td id="T_2ad4c_row4_col4" class="data row4 col4" >0.863500</td>
#       <td id="T_2ad4c_row4_col5" class="data row4 col5" >13.110000</td>
#       <td id="T_2ad4c_row4_col6" class="data row4 col6" >0.802000</td>
#     </tr>
#     <tr>
#       <th id="T_2ad4c_level0_row5" class="row_heading level0 row5" >RVI</th>
#       <td id="T_2ad4c_row5_col
